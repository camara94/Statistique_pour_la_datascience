# %% [markdown]
# # GRAPHIQUES BASIQUES POUR DECRIRE UNE VARIABLE

# %%
# Importation des librairies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
# Importation des données

df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Histogramme

# %%
# Histogramme du montant  de la consommation

sns.distplot(df.total_bill, kde=False, color="g").set_title('Consommation Totale');

# %%
# Histogramme du montant  de la consommation

sns.distplot(df.total_bill, color='b', bins=30, kde=False).set_title('Consommation Totale');

# %%
# Histogramme du montant  de la consommation

sns.distplot(df.total_bill, hist=False, color="b").set_title('Consommation Totale');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Histogramme du montant  de la consommation

sns.distplot(df.total_bill, bins=25, hist=True, kde=True, color="m").set_title('Consommation Totale');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Exemple de distribution normale

sns.distplot(np.random.normal(size=10000), kde=True).set_title("Distribution normale");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Importation du module stats de scipy

from scipy import stats
# Valeur aberrante se trouvente entre Q1 - 1.5IQR et Q3 + 1.5IQR

def finding_outliers(data, variable_name):
    iqr = stats.iqr(data[variable_name])
    q1 = data[variable_name].quantile(.25)
    q3 = data[variable_name].quantile(.75)
    
    lower = q1 - 1.5*iqr
    upper = q3 + 1.5*iqr
    
    outliers_df = data[(data[variable_name] < lower) | (data[variable_name] > upper) ]
    
    return outliers_df

# %%
finding_outliers(data=df, variable_name='total_bill')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %% [markdown]
# ## Boite à moustache

# %%
# Boîte à moustaches des pourbois

sns.boxplot(df.tip).set_title('Montant Des Pourbois');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Boîte à moustaches des pourbois

sns.boxplot(y=df.tip).set_title('Montant Des Pourbois');

# %%
# Boîte à moustaches de totale bill

s
